# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Load the dataset
data = pd.read_csv(r"C:\Users\Soujanya\Downloads\cust_data (1).csv")

# Drop unnecessary columns
data = data.drop(['Cust_ID', 'Gender'], axis=1)

# Normalize the data
scaler = StandardScaler()
normalized_data = scaler.fit_transform(data)

# Apply K-Means
k = 3  # Adjust this based on your analysis
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(normalized_data)

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to the original dataset
data['Cluster'] = cluster_labels

# Visualize clusters using PCA for dimensionality reduction
pca = PCA(n_components=2)
pca_data = pca.fit_transform(normalized_data)
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=cluster_labels, cmap='viridis')
plt.title('Cluster Visualization')
plt.show()

# Analyze cluster characteristics
cluster_characteristics = data.groupby('Cluster').mean()
print(cluster_characteristics)
# Out:
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#            Orders    Jordan  Gatorade   Samsung      Asus      Udis  \
# Cluster
# 0        4.057292  0.136204  0.136680  0.138323  0.074891  0.063476
# 1        4.638492  0.729271  0.656898  0.525911  0.492316  0.459971
# 2        4.153485  0.620204  0.574002  0.427565  0.276429  0.206735
#
#          Mondelez International  Wrangler      Vans      Fila  ...        LG  \
# Cluster                                                        ...
# 0                      0.089722  0.047390  0.061919  0.073204  ...  0.058330
# 1                      0.315940  0.317012  0.269299  0.170122  ...  0.132237
# 2                      0.274080  0.264683  0.316366  0.143305  ...  0.772905
#
#              Dior    Scabal  Tommy Hilfiger  Hollister  Forever 21  Colavita  \
# Cluster
# 0        0.152765  0.219830        0.084187   0.022312    0.020712  0.141696
# 1        0.657970  0.941744        0.336312   0.274124    0.179235  0.197105
# 2        0.719655  0.585748        0.736100   0.219264    0.186374  1.085356
#
#          Microsoft  Jiffy mix     Kraft
# Cluster
# 0         0.084360   0.055649  0.038180
# 1         0.167620   0.080415  0.037169
# 2         0.471417   0.707909  0.811276
#
# [3 rows x 36 columns]

# %%
from sklearn.metrics import silhouette_score
import warnings
from sklearn.exceptions import FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning)

silhouette_scores = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(normalized_data)
    silhouette_scores.append(silhouette_score(normalized_data, cluster_labels))

# Plot the Silhouette Score
plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.title('Silhouette Score')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 from sklearn.metrics import silhouette_score
#       2 import warnings
# ----> 3 from sklearn.exceptions import FutureWarning
#       4 warnings.filterwarnings("ignore", category=FutureWarning)
#       6 silhouette_scores = []
#
# ImportError: cannot import name 'FutureWarning' from 'sklearn.exceptions' (C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\exceptions.py)

# %%
optimal_k = silhouette_scores.index(max(silhouette_scores)) + 2  # Index starts from 2
kmeans = KMeans(n_clusters=optimal_k, n_init=10, random_state=42)
cluster_labels = kmeans.fit_predict(normalized_data)

# Add cluster labels to the original dataset
data['Cluster'] = cluster_labels

# Analyze cluster characteristics (mean values)
cluster_characteristics = data.groupby('Cluster').mean()
print(cluster_characteristics)
# Out:
#            Orders    Jordan  Gatorade   Samsung      Asus      Udis  \
# Cluster
# 0        4.138701  0.216649  0.209003  0.192444  0.138851  0.119830
# 1        4.431440  0.694697  0.616881  0.479448  0.350486  0.342956
#
#          Mondelez International  Wrangler      Vans     Fila  ...        LG  \
# Cluster                                                       ...
# 0                      0.118748  0.084474  0.092754  0.08522  ...  0.058293
# 1                      0.316599  0.295890  0.268591  0.17038  ...  0.474741
#
#              Dior    Scabal  Tommy Hilfiger  Hollister  Forever 21  Colavita  \
# Cluster
# 0        0.200239  0.310857        0.098870   0.047440    0.032969  0.136538
# 1        0.867587  0.868215        0.664575   0.331974    0.262316  0.660496
#
#          Microsoft  Jiffy mix     Kraft
# Cluster
# 0         0.087868   0.050647  0.034759
# 1         0.356134   0.402573  0.374961
#
# [2 rows x 36 columns]

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\soujanya\appdata\local\programs\python\python311\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\soujanya\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\soujanya\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\soujanya\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\soujanya\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv(r"C:\Users\Soujanya\Downloads\cust_data (1).csv")

# Drop unnecessary columns
data = data.drop(['Cust_ID', 'Gender'], axis=1)

# Normalize the data
scaler = StandardScaler()
normalized_data = scaler.fit_transform(data)

# Calculate silhouette scores for different values of k
silhouette_scores = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(normalized_data)
    silhouette_scores.append(silhouette_score(normalized_data, cluster_labels))

# Find the optimal number of clusters (k)
optimal_k = silhouette_scores.index(max(silhouette_scores)) + 2  # Index starts from 2

# Apply K-Means with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
cluster_labels = kmeans.fit_predict(normalized_data)

# Add cluster labels to the original dataset
data['Cluster'] = cluster_labels

# Print cluster characteristics (mean values)
cluster_characteristics = data.groupby('Cluster').mean()
print(cluster_characteristics)

# Plot the Silhouette Score
plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.title('Silhouette Score')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Soujanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#            Orders    Jordan  Gatorade   Samsung      Asus      Udis  \
# Cluster
# 0        4.138701  0.216649  0.209003  0.192444  0.138851  0.119830
# 1        4.431440  0.694697  0.616881  0.479448  0.350486  0.342956
#
#          Mondelez International  Wrangler      Vans     Fila  ...        LG  \
# Cluster                                                       ...
# 0                      0.118748  0.084474  0.092754  0.08522  ...  0.058293
# 1                      0.316599  0.295890  0.268591  0.17038  ...  0.474741
#
#              Dior    Scabal  Tommy Hilfiger  Hollister  Forever 21  Colavita  \
# Cluster
# 0        0.200239  0.310857        0.098870   0.047440    0.032969  0.136538
# 1        0.867587  0.868215        0.664575   0.331974    0.262316  0.660496
#
#          Microsoft  Jiffy mix     Kraft
# Cluster
# 0         0.087868   0.050647  0.034759
# 1         0.356134   0.402573  0.374961
#
# [2 rows x 36 columns]
